# %%
import LSTM
import torch
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Get data, 所有数据的第0号作为训练数据，其余作为测试数据

# %%
data = np.load('./databygroup.npy',allow_pickle=True).tolist()
TrainData,TestData={},{}
for k in data.keys():
    if '.csv0' in k:
        TrainData[k]=data[k]
    else:
        TestData[k]=data[k]
        
#Tdata=TrainData[TrainData.keys()]
step=20
xtrain,ytrain=[],[]
for k in TrainData.keys():
    for i in range(TrainData[k].shape[0]-step-1):
        xtrain.append(TrainData[k][i:i+step,1:TrainData[k].shape[1]-4].tolist())
        ytrain.append(TrainData[k][i+1+step,[-4,-3,-2,-1]].tolist())
    #xtrain.append(xtem)
    #ytrain.append(ytem)
xtrain = Variable(torch.FloatTensor(xtrain))
ytrain = Variable(torch.FloatTensor(ytrain))

# %% [markdown]
# # LSTM

# %% [markdown]
# ## 训练

# %%
param={
        'inputsize':xtrain.shape[2],
        'outputsize':ytrain.shape[1],
        'windowsize':xtrain.shape[1],
        'LSTM_hidden':10,
        'num_layer':1,
        'learning_rate':0.0001,
        'opt':'Adam',
    }

train=True
initial_train=True
net = LSTM.Net(param)
print(net)
if train:
    if not initial_train:
        net.model = torch.load('./model/LSTM')
    optimizer = torch.optim.Adam(net.parameters(),lr = param['learning_rate'])
    loss_func = torch.nn.MSELoss()
    mse=[]
    for t in range(5000):
        output = net(xtrain)
        loss = loss_func(output,ytrain)
        mse.append(loss.detach().numpy())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    torch.save(net,'./model/LSTM')        
    plt.plot(mse)
# Out:
# Net(
#   (lstm): LSTM(64, 10, batch_first=True, dropout=0.5)
#   (fc1): Linear(in_features=200, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=4, bias=True)
# )

# %%
yp = net(xtrain)
fig,ax=plt.subplots(4,1,figsize=(10,10))
for i in range(4):
    ax[i].plot(yp.detach().numpy()[:,i])
    ax[i].plot(ytrain.detach().numpy()[:,i])

# %% [markdown]
# ## 测试

# %%
for f in TestData.keys():
    step=20
    xtest,ytest=[],[]
    for i in range(TestData[f].shape[0]-step-1):
        xtest.append(TestData[f][i:i+step,1:TestData[f].shape[1]-4].tolist())
        ytest.append(TestData[f][i+1+step,[-4,-3,-2,-1]].tolist())
    xtest = Variable(torch.FloatTensor(xtest))
    ytest = Variable(torch.FloatTensor(ytest))
    print(xtest.shape,f)
    yp = net(xtest)
    #mse = np.sqrt(np.mean(np.square(y1.detach().numpy()-yp.detach().numpy())))
    pd.DataFrame(yp.detach().numpy()).to_csv('./results/LSTM/results_'+f)
    
    os.chdir(os.path.pardir)
    print(os.getcwd())
    pd.DataFrame(yp.detach().numpy()).to_csv('./Step4_Compare/results_p/LSTM/results_'+f)
    os.chdir('/Users/tianwenchong/Desktop/Text12-Koopman-WQ/Step3_DNN')
# Out:
# torch.Size([210, 20, 64]) 75.csv1
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([157, 20, 64]) 75.csv2
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([236, 20, 64]) 75.csv3
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([424, 20, 64]) 75.csv4
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([488, 20, 64]) 75.csv5
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([854, 20, 64]) 75.csv6
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([511, 20, 64]) 75.csv7
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([457, 20, 64]) 75.csv8
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([901, 20, 64]) 75.csv9
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([34, 20, 64]) 75.csv10
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([503, 20, 64]) 75.csv11
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([292, 20, 64]) 75.csv12
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([321, 20, 64]) 75.csv13
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([67, 20, 64]) 75.csv14
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([363, 20, 64]) 75.csv15
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([317, 20, 64]) 75.csv16
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([415, 20, 64]) 75.csv17
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([74, 20, 64]) 75.csv18
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([125, 20, 64]) 75.csv19
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([869, 20, 64]) 75.csv20
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([299, 20, 64]) 75.csv21
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([834, 20, 64]) 75.csv22
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([835, 20, 64]) 75.csv23
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([753, 20, 64]) 75.csv24
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([476, 20, 64]) 75.csv25
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([297, 20, 64]) 75.csv26
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([321, 20, 64]) 75.csv27
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([61, 20, 64]) 75.csv28
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([262, 20, 64]) 75.csv29
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([9, 20, 64]) 75.csv30
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([531, 20, 64]) 75.csv31
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([437, 20, 64]) 75.csv32
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([480, 20, 64]) 75.csv33
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([371, 20, 64]) 75.csv34
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([274, 20, 64]) 75.csv35
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([1049, 20, 64]) 75.csv36
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([277, 20, 64]) 75.csv37
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([411, 20, 64]) 75.csv38
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([583, 20, 64]) 75.csv39
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([276, 20, 64]) 75.csv40
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([22, 20, 64]) 75.csv41
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([8, 20, 64]) 75.csv42
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([93, 20, 64]) 75.csv43
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([124, 20, 64]) 75.csv44
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([486, 20, 64]) 75.csv45
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([549, 20, 64]) 75.csv46
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([54, 20, 64]) 75.csv47
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([45, 20, 64]) 75.csv48
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([962, 20, 64]) 75.csv49
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([801, 20, 64]) 75.csv50
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([60, 20, 64]) 75.csv51
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([647, 20, 64]) 75.csv52
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([499, 20, 64]) 75.csv53
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([518, 20, 64]) 75.csv54
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([295, 20, 64]) 75.csv55
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([23, 20, 64]) 75.csv56
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([231, 20, 64]) 75.csv57
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([399, 20, 64]) 75.csv58
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([10, 20, 64]) 75.csv59
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([308, 20, 64]) 75.csv60
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([214, 20, 64]) 75.csv61
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([540, 20, 64]) 75.csv62
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([1053, 20, 64]) 75.csv63
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([808, 20, 64]) 75.csv64
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([116, 20, 64]) 75.csv65
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([553, 20, 64]) 75.csv66
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([557, 20, 64]) 75.csv67
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([444, 20, 64]) 75.csv68
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([370, 20, 64]) 75.csv69
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
# torch.Size([67, 20, 64]) traindata
# /Users/tianwenchong/Desktop/Text12-Koopman-WQ
